# %%
import pandas as pd
import seaborn as sns

# %%
insurance_data = pd.read_csv("insurance.csv")

# %%
copy_data = insurance_data.copy()

# %%
copy_data['sex'] = copy_data['sex'].map({'male': 0, 'female': 1})

# %%
copy_data
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19  NaN  27.900         0     NaN  southwest  16884.92400
# 1      18  NaN  33.770         1     NaN  southeast   1725.55230
# 2      28  NaN  33.000         3     NaN  southeast   4449.46200
# 3      33  NaN  22.705         0     NaN  northwest  21984.47061
# 4      32  NaN  28.880         0     NaN  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50  NaN  30.970         3     NaN  northwest  10600.54830
# 1334   18  NaN  31.920         0     NaN  northeast   2205.98080
# 1335   18  NaN  36.850         0     NaN  southeast   1629.83350
# 1336   21  NaN  25.800         0     NaN  southwest   2007.94500
# 1337   61  NaN  29.070         0     NaN  northwest  29141.36030
#
# [1338 rows x 7 columns]
