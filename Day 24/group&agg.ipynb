# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data.csv")
df2 = df.copy()

df2.groupby("country")["income"].min()
df2.groupby("country")["income"].aggregate(Our_Mean = "mean", Minimum = "min", Maximum = "max")
# Out:
#          Our_Mean  Minimum  Maximum
# country
# Canada    62000.0  62000.0  62000.0
# China     51000.0  51000.0  51000.0
# India     73000.0  73000.0  73000.0
# Mexico    45000.0  45000.0  45000.0
# Spain         NaN      NaN      NaN
# USA       55400.0  47000.0  62000.0
