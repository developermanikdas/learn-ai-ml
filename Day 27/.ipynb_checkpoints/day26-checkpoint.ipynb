# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\manik\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\manik\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\manik\anaconda3\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

page_count = 1
is_page_over = False

data_list = []

while not is_page_over:
    URL = f"https://quotes.toscrape.com/page/{page_count}"
    res = requests.get(URL)
    if(res.status_code == 200):
        html_data = res.text
        print(res)

        soup = BeautifulSoup(html_data, "lxml")
        quote_list = soup.find_all("div", class_="quote")
        for quote in quote_list:
            tags = quote.find_all("a", class_="tag")
            for tag in tags:
                if(tag.text == "life"):
                    text = quote.find("span", class_="text").text   
                    author = quote.find("small", class_="author").text
                    data_list.append({"author": author, "text": text})
        page_count += 1
    else:
        is_page_over = True

print(data_list)
