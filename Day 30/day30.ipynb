# %%
import pandas as pd
import seaborn as sns

# %%
insurance_data = pd.read_csv("insurance.csv")

# %%
copy_data = insurance_data.copy()

# %%
copy_data['sex'] = copy_data['sex'].map({'male': 0, 'female': 1})
copy_data['smoker'] = copy_data['smoker'].map({'yes': 1, 'no': 0})

# %%
copy_data.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    1  27.900         0       1  southwest  16884.92400
# 1   18    0  33.770         1       0  southeast   1725.55230
# 2   28    0  33.000         3       0  southeast   4449.46200
# 3   33    0  22.705         0       0  northwest  21984.47061
# 4   32    0  28.880         0       0  northwest   3866.85520

# %%
# one hot encoding

X = copy_data.drop(columns = ['charges'])
y = copy_data['charges']

X = pd.get_dummies(X, columns=['region'], drop_first = False, dtype=int)

# %%
X.head()
# Out:
#    age  sex     bmi  children  smoker  region_northeast  region_northwest  \
# 0   19    1  27.900         0       1                 0                 0
# 1   18    0  33.770         1       0                 0                 0
# 2   28    0  33.000         3       0                 0                 0
# 3   33    0  22.705         0       0                 0                 1
# 4   32    0  28.880         0       0                 0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
from sklearn.model_selection import train_test_split

# Split into 80 train and 20% test
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.20, random_state=42
)

# %%
y_train.head()
# Out:
# 560      9193.83850
# 1285     8534.67180
# 1142    27117.99378
# 969      8596.82780
# 486     12475.35130
# Name: charges, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Make predictions
predictions = model.predict(X_test)
print(predictions)
# Out:
# [ 9110.19357296  7137.91369315 37115.05462904  9551.61248039
#  27133.04344439 10730.11176446   225.70883067 16873.11758652
#   1118.09410781 11321.10625889 28227.14309472  9435.2224553
#   4987.50843552 38350.39616955 40034.83683096 36975.10230012
#  15040.17833918 35847.37923653  8831.7085101  31721.07122575
#   3875.73115362 10023.62691025  2161.84776112  7213.89660063
#  11515.93670226 13016.54652485 14418.48180651  6381.60166813
#  10107.25694943  1741.83005255  9216.03490542 13144.1412802
#   4248.09850514  3607.59913551  4299.66539258 12990.2783496
#   1925.60155629  8763.61839975 33573.80097904 32405.59836056
#   4060.11662976  4337.23823668 14103.99235904 11367.57329365
#   8448.55170567 11927.94139229  5460.55786292  3191.72180416
#  35415.7728779   8830.30971813 15521.11195037  1956.15163842
#  12507.64501961  1414.99038569 12957.51136496 12615.46757705
#   4271.70296949 32479.62914071 13226.38219422 12953.03044087
# ...

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, predictions)
print(f'R2 score: {r2}')
# Out:
# R2 score: 0.7858188230456846

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Split into 80 train and 20% test
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.20, random_state=42
)

X['age_smoker'] = X['age']*X['smoker']
X['bmi_smoker'] = X['bmi']*X['smoker']

model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
print(f'R2 score: {r2}')
# Out:
# R2 score: 0.8669857364353448
