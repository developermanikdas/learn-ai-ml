# %%
#1 create a bank account class add methods like deposit, withdraw, balance_check

class BankAccount:
    def __init__(self, account_number, holder_name, balance):
        self.account_number = account_number
        self.holder_name = holder_name
        self.balance = balance
        
    def deposit(self, amount):
        self.balance += amount
        print(f"{self.balance} deposited successfully.")
        
     def withdraw(self, amount):
         self.balance -= amount  
         print(f"{elf.balance} withdrew successfully.")

     def check_balance(self):
         print(f"The balance is ${self.balance}.")    
         
p1 = BankAccount(123456, "Manik", 12_000)

p1.deposit(500)
p1.check_balance()
p1.withdraw(100)
p1.check_balance()
# Out:
#   File <string>:13
#     def withdraw(self, amount):
#                                ^
# IndentationError: unindent does not match any outer indentation level

# %%
#1 create a bank account class add methods like deposit, withdraw, balance_check

class BankAccount:
    def __init__(self, account_number, holder_name, balance):
        self.account_number = account_number
        self.holder_name = holder_name
        self.balance = balance
        
    def deposit(self, amount):
        self.balance += amount
        print(f"{self.balance} deposited successfully.")  # Fixed 'elf' to 'self'
        
    def withdraw(self, amount):  # Fixed indentation
        self.balance -= amount  
        print(f"{self.balance} withdrew successfully.")  # Fixed 'elf' to 'self'

    def check_balance(self):  # Fixed indentation
        print(f"The balance is ${self.balance}.")  # Changed p1.balance to self.balance
         
p1 = BankAccount(123456, "Manik", 12_000)

p1.deposit(500)
p1.check_balance()
p1.withdraw(100)
p1.check_balance()
# Out:
# 12500 deposited successfully.
# The balance is $12500.
# 12400 withdrew successfully.
# The balance is $12400.
